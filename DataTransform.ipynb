# %%
# Example of loading data into df
import pandas as pd

# Load data into df
df = pd.read_csv('loan_payments_data.xlsx')  # Adjust the file path accordingly
print(df)
# Out:
#              id  member_id  loan_amount  funded_amount  funded_amount_inv  \
# 0      38676116   41461848         8000         8000.0             8000.0
# 1      38656203   41440010        13200        13200.0            13200.0
# 2      38656154   41439961        16000        16000.0            16000.0
# 3      38656128   41439934        15000        15000.0            15000.0
# 4      38656121   41439927        15000        15000.0            15000.0
# ...         ...        ...          ...            ...                ...
# 54226     76597      76583         5000         5000.0             1775.0
# 54227    142608      74724         5000         5000.0             2350.0
# 54228    117045      70978         3500         3500.0             2225.0
# 54229     88854      70699         5000         5000.0              225.0
# 54230     72323      70694         5000         5000.0              350.0
#
#             term  int_rate  instalment grade sub_grade  ... recoveries  \
# ...

# %%
from data_transform import DataTransform

# Assuming df is your DataFrame
transformer = DataTransform(df)

# Specify columns to transform
date_columns = ['issue_date', 'last_payment_date', 'next_payment_date', 'last_credit_pull_date']
numeric_columns = ['loan_amount', 'funded_amount', 'int_rate', 'annual_inc']
categorical_columns = ['grade', 'sub_grade', 'home_ownership', 'loan_status', 'purpose']
columns_with_symbols = ['last_payment_amount']

# %%
# Apply transformations
df = transformer.convert_date_columns(date_columns)
df = transformer.convert_numeric_columns(numeric_columns)
df = transformer.convert_to_categorical(categorical_columns)
print(df)
# Out:
#              id  member_id  loan_amount  funded_amount  funded_amount_inv  \
# 0      38676116   41461848         8000         8000.0             8000.0
# 1      38656203   41440010        13200        13200.0            13200.0
# 2      38656154   41439961        16000        16000.0            16000.0
# 3      38656128   41439934        15000        15000.0            15000.0
# 4      38656121   41439927        15000        15000.0            15000.0
# ...         ...        ...          ...            ...                ...
# 54226     76597      76583         5000         5000.0             1775.0
# 54227    142608      74724         5000         5000.0             2350.0
# 54228    117045      70978         3500         3500.0             2225.0
# 54229     88854      70699         5000         5000.0              225.0
# 54230     72323      70694         5000         5000.0              350.0
#
#             term  int_rate  instalment grade sub_grade  ... recoveries  \
# ...
